# %% [markdown]
# <a href="https://colab.research.google.com/github/mruizdany/Repositorioprueba/blob/master/MartinezRuizDanielLeonardo_WebScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Automatización de la extracción de datos financieros para acciones**

# %% [markdown]
# ## **Introducción**

# %% [markdown]
# Se ha estado trabajando con una variedad de datos de acciones y está buscando recopilar datos fundamentales sobre un grupo selecto de acciones de energía. Hay muchas inversiones en ese campo. Algunas de esas empresas que se puede invertir son las siguientes cinco empresas del sector energético:
#
# Dominion Energy Inc. (Stock Symbol: D)
# Exelon Corp. (Stock Symbol: EXC)
# NextEra Energy Inc. (Stock Symbol: NEE)
# Southern Co. (Stock Symbol: SO)
# Duke Energy Corp. (Stock Symbol: DUK)
#
# Por el sector tan importante que genera grandes rentabilidades, en el siguiente trabajo se recopilará información sobre las ganancias por acción (EPS) de cada acción, la relación precio-ganancias (relación PE) y los datos de capitalización de mercado para tomar su decisión de inversión.
#
# En este ejerrcicio nos interesa que se haga de manera automatizada, para eso usamos la herramienta de Web scraping, que nos permite navegar por las paginas de internet extrayendo información mediante código con la ventaja que es de manera rapida y eficiente.

# %% [markdown]
# Problema: "¿Cómo podemos automatizar la recopilación de ganancias por acción (EPS), la relación precio-ganancias (relación PE) y los datos de capitalización de mercado?"
#
# Contexto analitico. En este caso, aprenderan la habilidad clave de web scraping: la práctica de tomar automáticamente información de las páginas web en línea, luego analizar y transformar esa información en un formato susceptible de análisis adicional.
#
# La estructura que tendremos es:
#
# 1.   Aprender los conceptos básicos de HTML, que gobierna casi todas las páginas web estáticas
# 2.   Analizar un documento HTML de muestra
# 3.   Extraer la información necesaria del documento HTML de una sola acción
# 4.   Escale este proceso a todos los símbolos; y (5) aprender a extraer el contenido de un documento HTML de una página web en vivo en tiempo real.

# %%
# Paquetes basicos para web-scraping
from IPython.core.display import HTML
from bs4 import BeautifulSoup
from IPython.display import IFrame
import urllib # paquete para interactuar con una pagina en vivo
import pandas as pd # almacenar la info de la pagina web

# %%
# conociendo el htlm
custom_html_doc = """
<html>
<head>
<title>HTML Page Title</title>
</head>
<h1>Head: Important Header: Global News</h1>
<br>
<h2>Head: Less Imporant Header: Global News</h2>
<body>
<p class="title"><b>Paragraph: Financial news</b></p>
<p class="story"> Stocks had a volatile week, where
<a href="https://finance.yahoo.com/quote/duk/" target="_blank" class="stock" id="link1">DUK</a>,
<a href="https://finance.yahoo.com/quote/d/" target="_blank" class="stock" id="link2">D</a>,
<a href="https://finance.yahoo.com/quote/exc/" target="_blank" class="stock" id="link3">EXC</a>,
<a href="https://finance.yahoo.com/quote/nee/" target="_blank" class="etf" id="link4">NEE</a>,
<a href="https://finance.yahoo.com/quote/so/" target="_blank" class="stock" id="link5">SO</a>,
were all making headlines.</p>
<p class="details">End of HTML document.</p>
"""

# %%
# Mirar el HTML asi como apareceria en un navegador
HTML(custom_html_doc)
# Out:
# <html>
# <head>
# <title>HTML Page Title</title>
# </head>
# <h1>Head: Important Header: Global News</h1>
# <br>
# <h2>Head: Less Imporant Header: Global News</h2>
# <body>
# <p class="title"><b>Paragraph: Financial news</b></p>
# <p class="story"> Stocks had a volatile week, where
# <a href="https://finance.yahoo.com/quote/duk/" target="_blank" class="stock" id="link1">DUK</a>,
# <a href="https://finance.yahoo.com/quote/d/" target="_blank" class="stock" id="link2">D</a>,
# <a href="https://finance.yahoo.com/quote/exc/" target="_blank" class="stock" id="link3">EXC</a>,
# <a href="https://finance.yahoo.com/quote/nee/" target="_blank" class="etf" id="link4">NEE</a>,
# <a href="https://finance.yahoo.com/quote/so/" target="_blank" class="stock" id="link5">SO</a>,
# were all making headlines.</p>
# <p class="details">End of HTML document.</p>

# %%
# Usando el standard html.parser para convertir el documento HTML en una estrcutura BeautifulSoup
soup = BeautifulSoup(custom_html_doc, 'html.parser')

# Imprimir el HTML con la identacion incluida 
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    HTML Page Title
#   </title>
#  </head>
#  <h1>
#   Head: Important Header: Global News
#  </h1>
#  <br/>
#  <h2>
#   Head: Less Imporant Header: Global News
#  </h2>
#  <body>
#   <p class="title">
#    <b>
#     Paragraph: Financial news
#    </b>
#   </p>
#   <p class="story">
#    Stocks had a volatile week, where
#    <a class="stock" href="https://finance.yahoo.com/quote/duk/" id="link1" target="_blank">
#     DUK
#    </a>
#    ,
#    <a class="stock" href="https://finance.yahoo.com/quote/d/" id="link2" target="_blank">
#     D
#    </a>
#    ,
#    <a class="stock" href="https://finance.yahoo.com/quote/exc/" id="link3" target="_blank">
#     EXC
#    </a>
#    ,
#    <a class="etf" href="https://finance.yahoo.com/quote/nee/" id="link4" target="_blank">
#     NEE
#    </a>
#    ,
#    <a class="stock" href="https://finance.yahoo.com/quote/so/" id="link5" target="_blank">
#     SO
#    </a>
#    ,
# were all making headlines.
#   </p>
#   <p class="details">
#    End of HTML document.
#   </p>
#  </body>
# </html>

# %%
# Seleccionemos primeros los tags 'a' ten soup (de forma predeterminada, se selecciona la primera aparición de una etiqueta)
tag = soup.a

# Imprimir el tag
print(tag)
# Out:
# <a class="stock" href="https://finance.yahoo.com/quote/duk/" id="link1" target="_blank">DUK</a>

# %%
# Mostrar todos los atributos del tag
print(tag.attrs)
# Out:
# {'href': 'https://finance.yahoo.com/quote/duk/', 'target': '_blank', 'class': ['stock'], 'id': 'link1'}

# %%
# Acceda al atributo de hipervínculo (use una etiqueta como un diccionario para acceder) 
print(tag['href'])
# Out:
# https://finance.yahoo.com/quote/duk/

# %%
# Ver todos los tags de hyperlink en el custom_html_doc
soup.find_all('a')
# Out:
# [<a class="stock" href="https://finance.yahoo.com/quote/duk/" id="link1" target="_blank">DUK</a>,
#  <a class="stock" href="https://finance.yahoo.com/quote/d/" id="link2" target="_blank">D</a>,
#  <a class="stock" href="https://finance.yahoo.com/quote/exc/" id="link3" target="_blank">EXC</a>,
#  <a class="etf" href="https://finance.yahoo.com/quote/nee/" id="link4" target="_blank">NEE</a>,
#  <a class="stock" href="https://finance.yahoo.com/quote/so/" id="link5" target="_blank">SO</a>]

# %%
for tag in soup.find_all('a'):
    print(tag['href'])
# Out:
# https://finance.yahoo.com/quote/duk/
# https://finance.yahoo.com/quote/d/
# https://finance.yahoo.com/quote/exc/
# https://finance.yahoo.com/quote/nee/
# https://finance.yahoo.com/quote/so/

# %%
custom_html_doc
# Out:
# '\n<html>\n<head>\n<title>HTML Page Title</title>\n</head>\n<h1>Head: Important Header: Global News</h1>\n<br>\n<h2>Head: Less Imporant Header: Global News</h2>\n<body>\n<p class="title"><b>Paragraph: Financial news</b></p>\n<p class="story"> Stocks had a volatile week, where\n<a href="https://finance.yahoo.com/quote/duk/" target="_blank" class="stock" id="link1">DUK</a>,\n<a href="https://finance.yahoo.com/quote/d/" target="_blank" class="stock" id="link2">D</a>,\n<a href="https://finance.yahoo.com/quote/exc/" target="_blank" class="stock" id="link3">EXC</a>,\n<a href="https://finance.yahoo.com/quote/nee/" target="_blank" class="etf" id="link4">NEE</a>,\n<a href="https://finance.yahoo.com/quote/so/" target="_blank" class="stock" id="link5">SO</a>,\nwere all making headlines.</p>\n<p class="details">End of HTML document.</p>\n'

# %%
s = BeautifulSoup(custom_html_doc, 'html.parser')
a_tag_list = s.find_all('a')
a_tag_list
# Out:
# [<a class="stock" href="https://finance.yahoo.com/quote/duk/" id="link1" target="_blank">DUK</a>,
#  <a class="stock" href="https://finance.yahoo.com/quote/d/" id="link2" target="_blank">D</a>,
#  <a class="stock" href="https://finance.yahoo.com/quote/exc/" id="link3" target="_blank">EXC</a>,
#  <a class="etf" href="https://finance.yahoo.com/quote/nee/" id="link4" target="_blank">NEE</a>,
#  <a class="stock" href="https://finance.yahoo.com/quote/so/" id="link5" target="_blank">SO</a>]

# %%
# Loop en cada uno de los tags
for tag in a_tag_list:
    symbol_name = tag.text
    class_name = tag['class'][0]
    #print(class_name)
    href_name = tag['href']
    print(symbol_name + ',' + class_name + ',' + href_name)
# Out:
# DUK,stock,https://finance.yahoo.com/quote/duk/
# D,stock,https://finance.yahoo.com/quote/d/
# EXC,stock,https://finance.yahoo.com/quote/exc/
# NEE,etf,https://finance.yahoo.com/quote/nee/
# SO,stock,https://finance.yahoo.com/quote/so/

# %%
import IPython
IPython.display.HTML
file_name="DUK_Yahoo.html"

# %%
# IFrame will allow us to view the HTML document
IFrame(src='DUK_Yahoo.html', width=800, height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="DUK_Yahoo.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Abrir el archivo file y pase el identificador del archivo (aquí el identificador del archivo es f) a BeautifulSoup
file_name = 'file:///C:/Users/Usuario/Documents/Python%20Scripts/DUK_Yahoo.html'
with open(file_name) as f:
  stock_soup = BeautifulSoup(f, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-7a55e3772ad1> in <module>()
#       1 # Abrir el archivo file y pase el identificador del archivo (aquí el identificador del archivo es f) a BeautifulSoup
#       2 file_name = 'file:///C:/Users/Usuario/Documents/Python%20Scripts/DUK_Yahoo.html'
# ----> 3 with open(file_name) as f:
#       4   stock_soup = BeautifulSoup(f, 'html.parser')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file:///C:/Users/Usuario/Documents/Python%20Scripts/DUK_Yahoo.html'

# %%
# Extraer los primeros 1000 characters y mirar un head del documento (no quiero imprimir demasiado para no quedar desordenado)
print(stock_soup.prettify()[:5000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-77ca0f5baf2c> in <module>()
#       1 # Extraer los primeros 1000 characters y mirar un head del documento (no quiero imprimir demasiado para no quedar desordenado)
# ----> 2 print(stock_soup.prettify()[:5000])
#
# NameError: name 'stock_soup' is not defined

# %%
stock_soup.find_all('td')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-23f1d887c560> in <module>()
# ----> 1 stock_soup.find_all('td')
#
# NameError: name 'stock_soup' is not defined

# %%
tag_list = []
for tag in stock_soup.find_all():
    tag_list.append(tag.name)

tag_count_dict = {}
for tag_name in tag_list:
    if tag_name in tag_count_dict:
        tag_count_dict[tag_name] = tag_count_dict[tag_name] + 1
    else:
        tag_count_dict[tag_name] = 1
        
tag_count_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-7577fb039a31> in <module>()
#       1 tag_list = []
# ----> 2 for tag in stock_soup.find_all():
#       3     tag_list.append(tag.name)
#       4
#       5 tag_count_dict = {}
#
# NameError: name 'stock_soup' is not defined

# %%
sorted(tag_count_dict.items(),key=lambda x: x[1],reverse=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-6d3df0176b6b> in <module>()
# ----> 1 sorted(tag_count_dict.items(),key=lambda x: x[1],reverse=True)
#
# NameError: name 'tag_count_dict' is not defined

# %%
# Nos gustaría seleccionar específicamente la etiqueta que contiene la información de capitalización de mercado para DUK
stock_soup.find_all("td")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-72a5893bb035> in <module>()
#       1 # Nos gustaría seleccionar específicamente la etiqueta que contiene la información de capitalización de mercado para DUK
# ----> 2 stock_soup.find_all("td")
#
# NameError: name 'stock_soup' is not defined

# %%
# Entonces, tneemos que buscar necesitamos buscar por más de una etiqueta -> agregar otro identificador para buscar
stock_soup.find("td", {"data-reactid":"81"}).text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-60586913cee3> in <module>()
#       1 # Entonces, tneemos que buscar necesitamos buscar por más de una etiqueta -> agregar otro identificador para buscar
# ----> 2 stock_soup.find("td", {"data-reactid":"81"}).text
#
# NameError: name 'stock_soup' is not defined

# %%
for i in stock_soup.find_all("td",{'class':['Ta(end)', 'Fw(b)', 'Lh(14px)']}):
    print(i.attrs['data-test'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-686362536304> in <module>()
# ----> 1 for i in stock_soup.find_all("td",{'class':['Ta(end)', 'Fw(b)', 'Lh(14px)']}):
#       2     print(i.attrs['data-test'])
#
# NameError: name 'stock_soup' is not defined

# %%
# Cargar el archivo
file_name = 'DUK_Yahoo.html'
with open(file_name) as f:
    stock_soup = BeautifulSoup(f, 'html.parser')

# Mi codigo:
bid = stock_soup.find("td", {"data-test" : 'BID-value'}).text
ask = stock_soup.find("td", {"data-test" : 'ASK-value'}).text
volume = stock_soup.find("td", {"data-test" : 'TD_VOLUME-value'}).text
average_volume = stock_soup.find("td", {"data-test" : 'AVERAGE_VOLUME_3MONTH-value'}).text

print("Bid: ", bid)
print("Ask: ", ask)
print("Volume: ", volume)
print("Avg. Volume: ", average_volume)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-43d424627f2e> in <module>()
#       1 # Cargar el archivo
#       2 file_name = 'DUK_Yahoo.html'
# ----> 3 with open(file_name) as f:
#       4     stock_soup = BeautifulSoup(f, 'html.parser')
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DUK_Yahoo.html'

# %%
# Definir la lista de simbolos a buscar a los que queremos aplicarles el parse
symbol_list = ['NEE','DUK','D','SO','EXC']

# %%
def process_yahoo(symbol):
    # Cargar los archivos previamente guardados
    file_name = symbol + '_Yahoo.html'
    with open(file_name) as f:
        s = BeautifulSoup(f, 'html.parser')
    
    # Analizar los datos de stock específicos de interés y almacenarlos en un objeto de diccionario 
    info_dict = {'MARKET_CAP' : s.find("td", {"data-test" : 'MARKET_CAP-value'}).text}
    
    return info_dict

# Recorra todos los símbolos, aplicando la función de análisis a cada uno de los archivos HTML correspondientes del símbolo.
fundamental_dict = {}
for sym in symbol_list:
    fundamental_dict[sym] = process_yahoo(sym)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-ef00f049a974> in <module>()
#      13 fundamental_dict = {}
#      14 for sym in symbol_list:
# ---> 15     fundamental_dict[sym] = process_yahoo(sym)
#
# <ipython-input-42-ef00f049a974> in process_yahoo(symbol)
#       2     # Cargar los archivos previamente guardados
#       3     file_name = symbol + '_Yahoo.html'
# ----> 4     with open(file_name) as f:
#       5         s = BeautifulSoup(f, 'html.parser')
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NEE_Yahoo.html'

# %%
# Look at the result
fundamental_dict
# Out:
# {}

# %%
def process_yahoo(symbol):
    # Definir las variables de interes del mercado a buscar 
    MARKET_CAP= "MARKET_CAP"
    PE_RATIO = "PE_RATIO"
    EPS_RATIO = "EPS_RATIO"
    
    # Cargar previamente los archivos guardados 
    file_name = symbol + '_Yahoo.html'
    with open(file_name) as f:
        s = BeautifulSoup(f, 'html.parser')
    
    # Analizar (Parse) los datos de stock específicos de interés y almacenarlos en un objeto de diccionario
    info_dict = {MARKET_CAP : s.find("td", {"data-test" : MARKET_CAP+'-value'}).text,
                 PE_RATIO : s.find("td", {"data-test" : PE_RATIO+'-value'}).text,
                 EPS_RATIO : s.find("td", {"data-test" : EPS_RATIO+'-value'}).text
                }
    
    return info_dict

# Recorrer todos los símbolos, aplicando la función de análisis a cada uno de los archivos HTML correspondientes del símbolo.
fundamental_dict = {}
for sym in symbol_list:
    fundamental_dict[sym] = process_yahoo(sym)
    
fundamental_dict
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-f832ee0421b9> in <module>()
#      21 fundamental_dict = {}
#      22 for sym in symbol_list:
# ---> 23     fundamental_dict[sym] = process_yahoo(sym)
#      24
#      25 fundamental_dict
#
# <ipython-input-44-f832ee0421b9> in process_yahoo(symbol)
#       7     # Cargar previamente los archivos guardados
#       8     file_name = symbol + '_Yahoo.html'
# ----> 9     with open(file_name) as f:
#      10         s = BeautifulSoup(f, 'html.parser')
#      11
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NEE_Yahoo.html'

# %%
def process_yahoo(symbol):
    # Definir las variables de interes del mercado a buscar 
    MARKET_CAP= "MARKET_CAP"
    PE_RATIO = "PE_RATIO"
    EPS_RATIO = "EPS_RATIO"
    
    # Cargar previamente los archivos guardados 
    file_name = symbol + '_Yahoo.html'
    with open(file_name) as f:
        s = BeautifulSoup(f, 'html.parser')
    
    # Analizar (Parse) los datos de stock específicos de interés y almacenarlos en un objeto de diccionario
    info_dict = {MARKET_CAP : s.find("td", {"data-test" : MARKET_CAP+'-value'}).text,
                 PE_RATIO : s.find("td", {"data-test" : PE_RATIO+'-value'}).text,
                 EPS_RATIO : s.find("td", {"data-test" : EPS_RATIO+'-value'}).text
                }
    
    return info_dict

# Recorrer todos los símbolos, aplicando la función de análisis a cada uno de los archivos HTML correspondientes del símbolo.
fundamental_dict = {}
for sym in symbol_list:
    fundamental_dict[sym] = process_yahoo(sym)
    
fundamental_dict
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-f832ee0421b9> in <module>()
#      21 fundamental_dict = {}
#      22 for sym in symbol_list:
# ---> 23     fundamental_dict[sym] = process_yahoo(sym)
#      24
#      25 fundamental_dict
#
# <ipython-input-45-f832ee0421b9> in process_yahoo(symbol)
#       7     # Cargar previamente los archivos guardados
#       8     file_name = symbol + '_Yahoo.html'
# ----> 9     with open(file_name) as f:
#      10         s = BeautifulSoup(f, 'html.parser')
#      11
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NEE_Yahoo.html'

# %% [markdown]
# ### **Live web scraping de data fundamental de stocks**

# %%
from io import BytesIO
import gzip
site_url='https://finance.yahoo.com/quote/DUK?p=DUK'
r = urllib.request.urlopen(site_url)
site_content = r.read()
site_content
# Out:
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x00\xec\xbd\xfbz\xdbF\xb28\xf8\xff<\x05\xcc\xc46yL@\xb8\x13$M{dI\x8e=#Y>\x92\x1co\xc6\xc7?~ \x00\x8a\x88A\x80\x01@]\xach\xbf}\x8d}\xbd}\x92\xad\xaan\x80\xb8Q\xa2\xe4\xcb$s\x12;&\xd0\xe8kUu]\xba\xbb\xaa\x9f>\xd8=\xdc9\xf9\xe5\xed\x9e0K\xe7\xc1\xb3\xa7\xf8\xaf\xe0\xbb\xa3\x96\x9dFs\xdfi\tN`\'\xc9\xa8\xf5&\xfaG"8\xb38\x9a{\x82\xeb%\x9f\xd2h!Lm?H\xec\xa9\xd7\x12\x02;<\x1d\xb5\xbcP|w\xdc\x82:<\xdb\x15\x16\xb17\xf5/F\xad\xe8t\x00U\xa7\x8b\xc1\xd6Vt\xba\x90\xe6\xdeV\x98\xfc\x00\x99\x12\'\xf6\x17\xe9\xb3s?t\xa3si\xe1\xc5\xd3(\x9e\xdb\xa1\xe3\t\x8f\x1e\t\xf5Tin\xc7\x9fn\xf8\xd4~\xfc\xd6>\xf5\x8eS;N\x1fw\x86O\xb7x\xf5O\xe7^jC\xbf\xed8\xf1\xd2Qk\x99NE\xab%l={\x9a\xfai\xe0=\xdb]~\xf2\x84\xbd\xd0\x8bO/\x85\x9d(^D\xb1\x9d\xfaQ(\xb4_E\x81\xeb\xc3\xef\xee\xbb\x7fv\x84\xe34r>\toc\xdf\xf1\xba\xc2\x1b\xef<\xe9\n\xff\xbd\x8cR\xe8\xa9=_\x0c\x85W~\x92F\xf1\xa5 \n\xbf\xd8\xb3(\x12^\xfa!v\xeb\xe9\x16k\x83u!\xb4\xe7\xde\xa8\xf5\xc9\xbb<\x8fb7\x01\xb0Fa\xea\x85\xd0%h\xa1+\xdc\xd2\x0f\xc8\xf0\xee\x9fBB\xdd\xc0\xb1\xa4\xb7\x96(g\xae\xbf\xc0\x10~\xc3!\xc0\xef\x94u\x97\xa0B]El\x89\xdeoK\xffl\xd4\xba\x10\xdd0\x11\x11\x97^\xea\xccD\xecu\x1c\x05\x85\xeeG\xe1\xaa\xe0"\x8e\x00-\xe9\xe5\xa8\x95\x9e\xfbi\xea\xc5\x037Lo\xcd;\x9d\x0c\xec\xc5b\xec\xbb\x85\x9c\xbaa\x19\x96\xaeZ\x96j\xf4T]Y\x15c`Lg\xde\xdc\x83\xce\x04Q\\(\xf4\x83.\xcbr_\xaef>\xf3\xbds\x00O\xb1#\xe7\xbe\x9b\xceF\xaew\x06\x18\x15\xe9\xa5+\xf8\xa1\x9f\xfav &\x8e\x1dx\xa3Z\x93@\xf3DQ>\x0e\xa2H\xee\xabZ\x01\xef\xae\x00]\x83\xcf\x00\xd8\xf4V\x141\xe2b\xb8!dt\x85\x19#\xa5\xae\x10\x02\x95\t6\xd4\x17A\x85\xb1p\xe6\xa76L\xcb\x90H\x9e*I#a\xe6\x05\x0b\xe12Z\xc2\x94Hg\xf8\x10\xf3\xca\xd2\xd8\x86\xfaO\xa9\xbc\x1f\x9eA_\xe0M\xaa\x8e(\xb2\xd3\xd9\xe0t\xe9x\x03\x18A\x02#\x10gQR\x84\x12~\x93.\x91\xa4%\'\x9aW\x8b\xcf\x933;\xf0]\x18\xaa$+\x85R\xdb}\xcbTw\xe4=sOy\xb1\xd77^\xec\xec\xc9/^j\xbb\xb2\xda\xb7^\xee\x1a\xd6\x0b\xaa\'\xf0\xc3OB\xec\x05P\x8d\x1d\xfaS\x0f\xdb\x9d\x01\x91\x8dZ[Y\x82\xf4k\xc2\xe9e\x95\xb9H\x8by\x81\xad@\xba\xf4\xe7\xa7y\x1fo\xcb\x9e\xdc-\xfb\xa9\x17I\xbf-\xbd\xf8\xb2\x02\x8a\xdb\xcaM\xa4\xc4\x89b\xcf\xb1c7\xf6\x12\xcf\x8e\x9d\xd9\xc6e}\xd6 \x9f\x99wlx\xea\xdc\xb1\xc0\x99\xefz\x91h/|\xe9\xf2\xb7\xe0\x8ee9\xe9H\xce|!!A\xdd\t\xac\xeb\x9a\x82\xdcPo\xe89i3\x92\x9d8J\x92(\xf6O\xfd\x10\xe4T\x18\x85\x97\xf3h\x99lPI\xf25*\xb9\x9d \x9aJmF\x0eM%7$\x86\xa6\xa27\x90BS\xf6\xcd\x08\xa1\xa9\xe4\x06d\xb0\x0e\x94wi\xc6v\x93\x9b\xf2\x07\x91\xedf\x99Q\x88%\x83"\xca\xb7\x96\xce\x16\x07\xe2\x96\xeb\x8a\x89\x9fz[S\xe0Z\xc9\x16\x89\xedc;L\x98\xe4F)p\xe4\x9d.\x03;\x16\xdf{\x13\xe9<\x9aN\xd5\x96`\x83\x16\x84\xf9[Bz\xb9\xf0\xd8\xf3\x16\xff\xb6)1}\xc5\x1e\x1ex\xae\xbf\x9c\xff\x81;x\xec\xcd\xfd\tH\xba?p\x17_|\xe3\xeem\x8d\xc7\xd0\x97\xe34\xf6@d\xc6"\xa8~\x9f\xbc\x18\x04\x1bk\x89\xbd\xdeZC\x0c\x13\xd2eyEERo.\xee;(4\xd7\x02\xc79\xdb\x82\xda\xce\xd4-\xd7\x9b\xda\xcb \xdd\xc2\xfc\xc9\xd6\xd4>\xc3\x87\xf1\xa5\xd2\x1fk\xea\x85\xa6\x8e\x9d%\xa8\x12s)9;m\t\x89\xff\xd9Kp\xcc\x97\x95\xc6\xec\x00t\xbc\x104\x00\xe1\xae\xcdN\x17[\xaa\xacX\xb2\xa5\x9a\xeb\xba \xc1k\x86\x07\x7f\x0e\xba\xfd\xd6\x85\xc8\x9a)\xf5\xc1AT\xf8\xa0\xb3U\x9b\xaf\xf1\xcb-\xd2\xb1\xb6@\xe9\xda\xbaIeE\x8a)\xa83\x7f\'\xb2yY\xd5\x91K\xea\xeb\x02z\x97l\xa2\xbd\xaeJ\x81UD\x83*\x94\xba\tnI\x84\xf4\xbaEE\x92-\x1a\xd2\x98\xc3r\x1cD\xa7\x91\xb4\x08O\xd74SR\\\xff|\xbaji,dP\x15m\xa7oh\xbe\xddh\xd6\xfc\xa7\xc04\x1b\xd0\xbf\x1b\xb0v0\xf0\xa3\x84\xec@,\xe3\x95\xadAM\xb5tE\xed\xc9\x8d3\xa9P\x14\r\x93B\xb1MZ\x05\x10\xc5\x91\xef\x0e\x96q\xd1\xa8\xf5\xe9\x17\xe6\xe2\x8ae\xfc\xf0\x9a\xd2\x86\x89\x83\xb6\xe7\xe8\x92\xb3\x97\xa1\xed `F\xbc\x1e\x89\x95\x94X\xaa\xf4\xf3\xeb\xbd\xf7\xc3\x85\xed|\x82i;\x82\t\xcd\x99\xd1<\x9a\xf8\x81\'9\x81Oyy\xd1\xac\xc6ci\x12G\xe7\x89\x17\x8f\xa7v\x10L\xa0\xf4\x18z7"\xf6\xf0P\xdb~\xa8\xbe\x84\xbf\x8b\xc0\xbe\x94N\xa3\xe8\x14\xeb\x89\xe6\x90Bp\x83_\x00D\x02?.\x0c\xd5\x0f\xa0\xc0K\xdf}\xa8\xedn\xda\xb8\x17\xba\xb7@\xea\x0b\x01\xcd\xa1Q(\xbda\xd7\xaa\xf6\'\xf4#\xf0D?]\x86^\x02:\xeb\xa2P#\xbc\x89\xbe;\xca\xc9\xa6+`\nT\xbb\x10\' ...

# %%
type(site_content)
# Out:
# bytes

# %%
from io import BytesIO
import gzip

buff = BytesIO(site_content)
f = gzip.GzipFile(fileobj=buff)
site_content = f.read().decode('utf-8')
site_content
# Out:
# '<!DOCTYPE html><html id="atomic" class="NoJs chrome desktop failsafe" lang="en-US"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark(\'PageStart\');</script><meta charset="utf-8" /><title>Duke Energy Corporation (Holdin (DUK) Stock Price, News, Quote &amp; History - Yahoo Finance</title><meta name="keywords" content="DUK, Duke Energy Corporation (Holdin, DUK stock chart, Duke Energy Corporation (Holdin stock chart, stock chart, stocks, quotes, finance" /><meta http-equiv="x-dns-prefetch-control" content="on" /><meta property="twitter:dnt" content="on" /><meta property="fb:app_id" content="458584288257241" /><meta name="theme-color" content="#400090" /><meta name="viewport" content="width=device-width, initial-scale=1" /><meta name="description" lang="en-US" content="Find the latest Duke Energy Corporation (Holdin (DUK) stock quote, history, news and other vital information to help you with your stock trading and investing." /><meta name="oath:guce:consent-host" content="guce.yahoo.com" /><meta name="msvalidate.01" content="A9862C0E6E1BE95BCE0BF3D0298FD58B" /><link rel="manifest" href="/manifest.json" /><link rel="dns-prefetch" href="//l.yimg.com" /><link rel="dns-prefetch" href="//s.yimg.com" /><link rel="dns-prefetch" href="//geo.query.yahoo.com" /><link rel="dns-prefetch" href="//b.scorecardresearch.com" /><link rel="dns-prefetch" href="//iquery.finance.yahoo.com" /><link rel="dns-prefetch" href="//fc.yahoo.com" /><link rel="dns-prefetch" href="//video-api.yql.yahoo.com" /><link rel="dns-prefetch" href="//consent.cmp.oath.com" /><link rel="dns-prefetch" href="//geo.yahoo.com" /><link rel="preconnect" href="//l.yimg.com" crossorigin="anonymous" /><link rel="preconnect" href="//s.yimg.com" crossorigin="anonymous" /><link rel="preconnect" href="//geo.query.yahoo.com" /><link rel="preconnect" href="//b.scorecardresearch.com" /><link rel="preconnect" href="//iquery.finance.yahoo.com" /><link rel="preconnect" href="//fc.yahoo.com" /><link rel="preconnect" href="//video-api.yql.yahoo.com" /><link rel="preconnect" href="//consent.cmp.oath.com" /><link rel="preconnect" href="//geo.yahoo.com" /><link rel="preconnect" href="//ads.yahoo.com" /><link rel="preload" href="https://s.yimg.com/uc/finance/dd-site/fonts/YahooSansFinancial-Regular-Web.woff2" as="font" type="font/woff2" crossorigin="anonymous" /><link rel="preload" href="https://s.yimg.com/uc/finance/dd-site/fonts/YahooSansFinancial-Medium-Web.woff2" as="font" type="font/woff2" crossorigin="anonymous" /><link rel="preload" href="https://s.yimg.com/uc/finance/dd-site/fonts/YahooSansFinancial-Semibold-Web.woff2" as="font" type="font/woff2" crossorigin="anonymous" /><link rel="preload" href="https://s.yimg.com/uc/finance/dd-site/fonts/YahooSansFinancial-Bold-Web.woff2" as="font" type="font/woff2" crossorigin="anonymous" /><link rel="preload" href="/__finStreamer-worker.js" as="worker" /><link rel="preload" href="/__rapidworker-1.2.js" as="worker" /><link rel="icon" href="https://s.yimg.com/cv/apiv2/default/icons/favicon_y19_32x32_custom.svg" sizes="any" /><link rel="alternate icon" href="https://s.yimg.com/cv/apiv2/default/fp/20180826/icons/favicon_y19_32x32.ico" type="image/x-icon" /><link rel="canonical" href="https://finance.yahoo.com/quote/DUK/" /><meta property="twitter:site" content="@YahooFinance" /><meta property="fb:pages" content="458584288257241" /><meta property="og:image" content="https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png" /><meta property="og:description" content="Find the latest Duke Energy Corporation (Holdin (DUK) stock quote, history, news and other vital information to help you with your stock trading and investing." /><meta property="og:title" content="Duke Energy Corporation (Holdin (DUK) Stock Price, News, Quote &amp; History - Yahoo Finance" /><meta property="twitter:description" content="Find the latest Duke Energy Corporation (Holdin (DUK) stock quote, history, news a ...

# %%
# Guardar el scraped HTML en un .html file (para procesamiento posterior)
with open('saved_page.html', 'w',encoding='utf-8') as f:
    f.write(site_content)

# Usar el html.parser para crear el soup
s = BeautifulSoup(site_content, 'html.parser')

# %%
# Mirar el objeto soup object con el  metodo prettify()
print(s.prettify()[:500]) # Solo mostrar una porcion del texto ya que es largo
# Out:
# <!DOCTYPE html>
# <html class="NoJs chrome desktop failsafe" id="atomic" lang="en-US">
#  <head prefix="og: http://ogp.me/ns#">
#   <script>
#    window.performance && window.performance.mark && window.performance.mark('PageStart');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Duke Energy Corporation (Holdin (DUK) Stock Price, News, Quote &amp; History - Yahoo Finance
#   </title>
#   <meta content="DUK, Duke Energy Corporation (Holdin, DUK stock chart, Duke Energy Corporation (Holdin stock chart, sto

# %%
symbol_list = ['NEE','DUK','D','SO','EXC'] # stocks of interest

def scrape_yahoo(symbol):
    symbol_url='https://finance.yahoo.com/quote/' + symbol
    MARKET_CAP= "MARKET_CAP"
    PE_RATIO = "PE_RATIO"
    EPS_RATIO = "EPS_RATIO"
    
    # Scrape
    r = urllib.request.urlopen(symbol_url)
    c = r.read()
    ############ IMPORTANTE EL BytesIO#################
    buff = BytesIO(c)
    f = gzip.GzipFile(fileobj=buff)
    ################################################3
    c = f.read().decode('utf-8')
    s = BeautifulSoup(c, 'html.parser')
    
    info_dict = {MARKET_CAP : s.find("td", {"data-test" : MARKET_CAP+'-value'}).text,
                 PE_RATIO : s.find("td", {"data-test" : PE_RATIO+'-value'}).text,
                 EPS_RATIO : s.find("td", {"data-test" : EPS_RATIO+'-value'}).text
                }
    
    return info_dict

# Scrape los datos, y almacenarlos en un diccionario
symbol_dict = {}
for symbol in symbol_list:
    print("Scraping Symbol: " + symbol)
    symbol_dict[symbol] = scrape_yahoo(symbol)
    
# Mostrar la data con parsing
fundamental_df = pd.DataFrame.from_dict(symbol_dict, orient='index')
fundamental_df
# Out:
# Scraping Symbol: NEE
# Scraping Symbol: DUK
# Scraping Symbol: D
# Scraping Symbol: SO
# Scraping Symbol: EXC
#     MARKET_CAP PE_RATIO EPS_RATIO
# NEE   167.822B   139.30      0.61
# DUK    78.711B    26.75      3.83
# D      61.776B    27.64      2.76
# SO      66.23B    21.20      2.95
# EXC    52.966B    31.66      1.71
